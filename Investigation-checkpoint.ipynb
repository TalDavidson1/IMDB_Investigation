# %% [markdown]
# # Overview
# For this project I  will be using the IMDB dataset.
#
# This data set contains 20 columns and over 10 thousand rows of movie data such as the cast, budget, genre etc.

# %% [markdown]
# #### Questions
# 1. What genre has the most movies.
# 2. What genre has the most movies per year on average
# 3. Genre with the least profit
# 4. Genre with the most profit

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
df_plain = pd.read_csv('imdb_movies.csv')
df_plain.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# # General investigation

# %%
# view the tail of the data
df_plain.tail()
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
# ...

# %%
#Data dimensions 
df_plain.shape
# Out:
# (10866, 21)

# %%
#get column types
df_plain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
#See if the release date column is a str

type(df_plain['release_date'][0])
# Out:
# str

# %% [markdown]
# # Obsevations thus far
# No unit of currency is mentioned in the dataset. For the purpose of this investigation the budget column and revenue column will be taken as US Dollar

# %% [markdown]
# # Data Cleaning

# %%
# split the genre column to be more readable
split_cols = df_plain['genres'].str.split('|',expand=True)
df = df_plain.join(split_cols)
df = df.rename(columns ={0:"genre"})
df = df.drop(["genres", 1,2,3,4], axis = 1)
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
#remove unwanted and unused columns
del_col = [ 'id', 'imdb_id', 'popularity', 'budget_adj', 'revenue_adj', 'homepage', 'keywords', 'overview', 'production_companies', 'vote_count', 'vote_average']
df = df.drop(columns=del_col)

df.head()
# Out:
#       budget     revenue                original_title  \
# 0  150000000  1513528810                Jurassic World
# 1  150000000   378436354            Mad Max: Fury Road
# 2  110000000   295238201                     Insurgent
# 3  200000000  2068178225  Star Wars: The Force Awakens
# 4  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime release_date  release_year  \
# 0              The park is open.      124     6/9/2015          2015
# ...

# %%
#make release date a date time
df.release_date = pd.to_datetime(df['release_date'])
df.head()
# Out:
#       budget     revenue                original_title  \
# 0  150000000  1513528810                Jurassic World
# 1  150000000   378436354            Mad Max: Fury Road
# 2  110000000   295238201                     Insurgent
# 3  200000000  2068178225  Star Wars: The Force Awakens
# 4  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime release_date  release_year  \
# 0              The park is open.      124   2015-06-09          2015
# ...

# %%
#Remove any duplicates
df.drop_duplicates(keep ='first', inplace=True)

# %%
df.shape
# Out:
# (10865, 10)

# %%
#This is to make sure any cell with a value of 0 in the revenue or budget column is changed to NAN because that can greatly skew our data
#Make a list
temp_list=['budget', 'revenue']

#make the replacement
df[temp_list] = df[temp_list].replace(0, np.NAN)

#Removing all the row which has NaN value in temp_list 
df.dropna(subset = temp_list, inplace = False)
df.shape
# Out:
# (10865, 10)

# %% [markdown]
# # 1d exploration of revenue per year

# %%
# Group the data by 'release_year' and calculate the total revenue for each year
revenue_by_year = df.groupby('release_year')['revenue'].sum()

# Generate the line plot
plt.figure(figsize=(12, 6))
plt.plot(revenue_by_year.index, revenue_by_year.values, linestyle='-', color='steelblue')
plt.xlabel('Release Year')
plt.ylabel('Revenue')
plt.title('Revenue Distribution by Year')
plt.grid(True)
plt.show()

# %% [markdown]
# # Pie Chart to display the revenue per genre

# %%
# Group the data by 'genre' and calculate the total revenue for each genre
revenue_by_genre = df.groupby('genre')['revenue'].sum()

# Generate the pie chart
plt.figure(figsize=(10, 10))
plt.pie(revenue_by_genre.values, labels=revenue_by_genre.index, autopct='%1.1f%%', startangle=90, textprops={'fontsize': 8})
plt.title('Total Revenue by Genre')
plt.axis('equal')

# Add a legend with the genre labels and percentage contribution
plt.legend(labels=revenue_by_genre.index, loc='best')

plt.show()

# %% [markdown]
# # What genre has the most movies?

# %%
# Per my reviewers feedback I am making this function to stop as much repetition in my code for plotting.
def create_bar_chart(x, y, x_label, y_label, title):
    plt.figure(figsize=(12, 6))
    plt.bar(x, y, alpha=1, align="center", color="steelblue")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.xticks(rotation=90)
    plt.show()

# %%
# The number of movies per genre
grouped_data = df.groupby('genre')['genre'].count()
sorted_genres = grouped_data.sort_values(ascending=False).index
create_bar_chart(sorted_genres, grouped_data.loc[sorted_genres], "Genres", "Number of Movies", "Number of Movies per Genre")

# %% [markdown]
# # Observation
# The movie genre with the most movies is Drama, followed closely by Comedy and Action, those 3 together seem to be much higher then all the other categories.

# %% [markdown]
# # What genre has the most movies per year on average?

# %%
#using the same function created in the last section I am creating this bar chart for movies per year on average per genre
grouped_data = df.groupby('genre')['release_year'].nunique()
average_movies_per_year = grouped_data.mean()
sorted_genres = grouped_data.sort_values(ascending=False).index
create_bar_chart(sorted_genres, grouped_data.loc[sorted_genres], "Genres", "Average Number of Movies per Year", "Average Movies per Genre per Year")

# %% [markdown]
# # Observation
# The average per year per genre seems to tell a good story, even though drama is still the highest on the list it is much closer to the other genres, the reason for this could possibly be that darama had a few year span of large amounts of movies but does not on average have many per year

# %% [markdown]
# # Genre with the least profit

# %%
#add a column for profit
df['profit'] = df['revenue'] - df['budget']
df.head()
# Out:
#         budget       revenue                original_title  \
# 0  150000000.0  1.513529e+09                Jurassic World
# 1  150000000.0  3.784364e+08            Mad Max: Fury Road
# 2  110000000.0  2.952382e+08                     Insurgent
# 3  200000000.0  2.068178e+09  Star Wars: The Force Awakens
# 4  190000000.0  1.506249e+09                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  runtime release_date  release_year  \
# 0              The park is open.      124   2015-06-09          2015
# ...

# %%
# Group the data by genre and profit
genre_profit = df.groupby('genre')['profit'].sum().reset_index()
#sort the genres in asc
genre_profit_sorted = genre_profit.sort_values('profit')
#get least profitable genre
least_profit_genre = genre_profit_sorted.iloc[0]['genre']
print("The genre with the least profit is:", least_profit_genre)
# Out:
# The genre with the least profit is: Foreign

# %% [markdown]
# # Observation
# The genre with the least profit is Foreign

# %% [markdown]
# # Genre with the most profit

# %%
# Group the data by genre and profit
genre_profit = df.groupby('genre')['profit'].sum().reset_index()
#sort the genres in asc
genre_profit_sorted = genre_profit.sort_values('profit', ascending=False)
#get most profitable genre
most_profit_genre = genre_profit_sorted.iloc[0]['genre']
print("The genre with the most profit is:", most_profit_genre)
# Out:
# The genre with the most profit is: Action

# %% [markdown]
# # Observation
# The genre with the most profit is Action

# %% [markdown]
# # Conclusion

# %% [markdown]
# # After my analysis of this dataset here are the final thoughts
# 1. The Drama and Comedy genres have significantly more movies overall then all other categories
# 2. On average per year the Drama category is still the highest, however it is much closer to the rest of the genres this leads me to believe that drama had a few very large years that brought it up so high overall but yet not on average, which opens up more questions for future analysis.
# 3. The Foreign genre has the least profit and the least movies overall as well as the least on average per year which makes my analysis suggest investors and directors should stay away from this genre
# 4. The Action genre has the highest profit of any genre, the third most overall movies and the most on average per year, which leads my analysis to suggest that action movies are a great genre to be in currently.
#
# A big limitation of this dataset is that the revenue and budget columns are not categorized or stated into any one currency, for example if the revenue is 50% in Yen and 50% of the revenue is in USD but 100% of the budget is in USD then the movie would actually be a huge loss where this dataset shows it as a profit.

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigation.ipynb'])
# Out:
# 1
